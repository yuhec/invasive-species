# %% [markdown]
# # Import Data

# %%
import os
 
os.environ['KAGGLE_USERNAME'] = "tuankirie"
os.environ['KAGGLE_KEY'] = "72957789db0f16c86ec351b1b91407f3"

# %%
# %%bash
# #cd ISM/data/
# #kaggle competitions download -c invasive-species-monitoring
#
# #unzip invasive-species-monitoring.zip && rm invasive-species-monitoring.zip
#
# #unzip sample_submission.csv.zip && rm sample_submission.csv.zip
# #unzip train_labels.csv.zip && rm train_labels.csv.zip
# #py7zr x test.7z && rm test.7z
# py7zr x train.7z && rm train.7z
